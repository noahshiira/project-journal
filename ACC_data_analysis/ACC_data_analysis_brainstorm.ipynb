# %% [markdown]
# ### I want to make some visualizations that are helpful for the datasets
# some ideas:
# - do some basic metrics
# - make sure to drop the first row (John DellOmo) beause it's just an example
